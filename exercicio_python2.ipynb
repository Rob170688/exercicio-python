# %% [markdown]
# Questão 1.

# %%
print("Alunos - PLP Unifavip 2024.2")
# Out:
# Alunos - PLP Unifavip 2024.2

# %% [markdown]
# Questão 2.

# %%
numero=int(input("Digite um número: "))
print("O número informado foi:",numero)
# Out:
# Digite um número: 5
# O número informado foi: 5

# %% [markdown]
# Questão 3.

# %%
numero1=int(input("Digite um número: "))
numero2=int(input("Digite outro número: "))
soma=numero1+numero2
print("A soma dos números é:",soma)
# Out:
# Digite um número: 5
# Digite outro número: 5
# A soma dos números é: 10

# %% [markdown]
# Questão 4.

# %%
nota1=float(input("Digite a primeira nota: "))
nota2=float(input("Digite a segunda nota: "))
nota3=float(input("Digite a terceira nota: "))
nota4=float(input("Digite a quarta nota: "))
media=(nota1+nota2+nota3+nota4)/4
print("A média do aluno será: ",media)
# Out:
# Digite a primeira nota: 5.9
# Digite a segunda nota: 6.2
# Digite a terceira nota: 5.6
# Digite a quarta nota: 9
# A média do aluno será:  6.675000000000001

# %% [markdown]
# Questão 5.

# %%
metros=float(input("Adicione sua altura em metros: "))
centimetros=metros*100
print("Sua altura será em centimetros:",centimetros)
# Out:
# Adicione sua altura em metros: 1.70
# Sua altura será em centimetros: 170.0

# %% [markdown]
# Questão 11.

# %%
numero1=int(input("Digite o primeiro número: "))
numero2=int(input("Digite o segundo número: "))
numero_real=float(input("Digite o último número: "))
a=(numero1*2)*(numero2/2)
b=(numero1*3)+numero_real
c=numero_real*numero_real*numero_real
print("a. ",a)
print("b. ",b)
print("c. ",c)
# Out:
# Digite o primeiro número: 5
# Digite o segundo número: 6
# Digite o último número: 6.5
# a.  30.0
# b.  21.5
# c.  274.625

# %% [markdown]
# Questão 33.

# %%
for i in range(13):
 nome=input("Digite o nome do aluno: ")
 matricula=input("Digite a mátricula do aluno: ")
 nota1=float(input("Digite a primeira nota do aluno: "))
 nota2=float(input("Digite a segunda nota do aluno: "))
 media=(nota1+nota2)/2
 print("O aluno: ", nome)
 print("Da mátricula: ", matricula)
 print("Sua média será: ", media)
